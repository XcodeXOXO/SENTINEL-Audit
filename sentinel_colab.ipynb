# %%
import torch

# 1. Verify GPU is active (Crucial to prevent CPU crashes)
if not torch.cuda.is_available():
    raise SystemError("❌ GPU not detected! Go to Runtime > Change runtime type > Select T4 GPU.")
else:
    print(f" GPU Active: {torch.cuda.get_device_name(0)}")

# 2. Install the Sentinel Engine
# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install unsloth_zoo
# !pip install --no-deps xformers trl peft accelerate bitsandbytes
# !pip install rich tabulate tqdm hf_transfer

import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
print(" Environment Installed Successfully.")
# Out:
#  GPU Active: Tesla T4
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-wucti3t0/unsloth_5153406ea0464bff849f278e186d1df3
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-wucti3t0/unsloth_5153406ea0464bff849f278e186d1df3
#   Resolved https://github.com/unslothai/unsloth.git to commit 5aa8c152468cd741949c72187dcb0702a1f11f43
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#  Environment Installed Successfully.

# %%
from google.colab import drive
import os
import time

drive.mount('/content/drive')

project_path = '/content/drive/MyDrive/Audit-smart/'

# 3. The Sync Guard: Waits for Google Drive to actually load your files
print("⏳ Verifying connection to Project Sentinel...")
retries = 5
while not os.path.exists(f"{project_path}sentinel_cli.py") and retries > 0:
    time.sleep(2)
    retries -= 1

if os.path.exists(f"{project_path}sentinel_cli.py"):
    # %cd {project_path}
    print("Successfully connected to IDE project directory!")
else:
    print("Error: Could not find sentinel_cli.py. Check your Drive path.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ⏳ Verifying connection to Project Sentinel...
# /content/drive/MyDrive/Audit-smart
# Successfully connected to IDE project directory!

# %%
# Execute the CLI on the Reentrancy test
# We point --weights to the EXACT folder where your fine-tuned model lives
# !python sentinel_cli.py --contract tests/vulnerable_contracts/integer_overflow.sol --weights /content/drive/MyDrive/Sentinel_Project/Llama3_Sentinel_v1 --save-report
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │          ███████╗███████╗███╗   ██╗████████╗██╗███╗   ██╗███████╗██╗         │
# │          ██╔════╝██╔════╝████╗  ██║╚══██╔══╝██║████╗  ██║██╔════╝██║         │
# │          ███████╗█████╗  ██╔██╗ ██║   ██║   ██║██╔██╗ ██║█████╗  ██║         │
# │          ╚════██║██╔══╝  ██║╚██╗██║   ██║   ██║██║╚██╗██║██╔══╝  ██║         │
# │        ███████║███████╗██║ ╚████║   ██║   ██║██║ ╚████║███████╗███████╗      │
# │        ╚══════╝╚══════╝╚═╝  ╚═══╝   ╚═╝   ╚═╝╚═╝  ╚═══╝╚══════╝╚══════╝      │
# │                Autonomous Smart Contract Security Auditor  •  v1.0.0         │
# │                 Fine-tuned Llama-3-8B @ LoRA Rank 16  •  BCCC-VulSCs         │
# │                                                                              │
# │                                                                              │
# ...
